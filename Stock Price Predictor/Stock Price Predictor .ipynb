# %%
import pandas as pan   
import matplotlib.pyplot as plt 
import yfinance as fin 
import numpy as num 
import seaborn as sb 
  
# %matplotlib inline

# %%
stocks = input("Enter the code of the stock:- ") 
data = fin.download(stocks, "2021-04-01", "2022-03-31", auto_adjust=True) 
data.head()
# Out:
# Enter the code of the stock:- GOOGL
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close    Volume
# Date
# 2021-03-31  102.720001  104.313004  102.349998  103.125999  42570000
# 2021-04-01  104.612503  106.787498  104.571503  106.488998  39880000
# 2021-04-05  107.357498  111.449501  107.260498  110.947998  48510000
# 2021-04-06  110.545998  111.400002  110.089500  110.462997  35240000
# 2021-04-07  110.654999  112.224998  110.654999  111.951500  24134000

# %%
data.shape
# Out:
# (253, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 253 entries, 2021-03-31 to 2022-03-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    253 non-null    float64
#  1   High    253 non-null    float64
#  2   Low     253 non-null    float64
#  3   Close   253 non-null    float64
#  4   Volume  253 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 11.9 KB

# %%
data.describe()
# Out:
#              Open        High         Low       Close        Volume
# count  253.000000  253.000000  253.000000  253.000000  2.530000e+02
# mean   133.115597  134.311503  131.754451  133.082257  3.119515e+07
# std     11.481949   11.540092   11.238668   11.338311  1.354679e+07
# min    102.720001  104.313004  102.349998  103.125999  1.430200e+07
# 25%    122.678497  123.055496  121.834503  122.508499  2.239000e+07
# 50%    136.101501  137.184006  134.550003  136.022995  2.749400e+07
# 75%    142.647507  143.834503  140.912003  142.078995  3.557600e+07
# max    151.250000  151.546494  148.899002  149.838501  1.232000e+08

# %%
data.Close.plot(figsize=(10, 7),color='r')
plt.ylabel("{} Prices".format(stocks))
plt.title("{} Price Series".format(stocks))
plt.show()

# %%
sb.distplot(data["Close"])
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_9996\4128163586.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(data["Close"])
# <AxesSubplot: xlabel='Close', ylabel='Density'>

# %%
sb.distplot(data["Open"])
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_9996\2725614008.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(data["Open"])
# <AxesSubplot: xlabel='Open', ylabel='Density'>

# %%
sb.distplot(data["High"])
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_9996\3861871830.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(data["High"])
# <AxesSubplot: xlabel='High', ylabel='Density'>

# %%
# Conlusions  

# - Shape the of the data  
# - how our data is distributed 
# - It's very very non linear  

# Linear, Logis, Regularized, SVM 

X = data.drop("Close", axis=1) 
y = data["Close"] 

from sklearn.model_selection import train_test_split 

X_train, X_test, y_train, y_test  = train_test_split(X,y,test_size=0.2, random_state=0) 
print(X_train.shape) 
print(X_test.shape) 
print(y_train.shape) 
print(y_test.shape)
# Out:
# (202, 4)
# (51, 4)
# (202,)
# (51,)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression() 
lr.fit(X_train, y_train) 
pred1 = lr.predict(X_test)

# %%
# MSE -- > Mean Squared  
# RMSE ---> sart(MSE) 
# r2_square ---> 1.0 # good model 

from sklearn.metrics import mean_squared_error, r2_score 


def calculate_metrics(y_test, y_pred):  
    ''' 
    y_test:- ground truth 
    y_pred:- model predict  
    '''
    mse = mean_squared_error(y_test, y_pred) 
    rmse = num.sqrt(mse) 
    r2_scors = r2_score(y_test, y_pred) 
    
    print("MSE:- ", mse) 
    print("RMSE:- ", rmse) 
    print("R2_score:- ", r2_scors) 
    
calculate_metrics(y_test, pred1)
# Out:
# MSE:-  0.577663380194261
# RMSE:-  0.7600416963524179
# R2_score:-  0.9946836689083671

# %%
from sklearn.linear_model import Lasso, Ridge 

la = Lasso().fit(X_train, y_train )
rr = Ridge(alpha=0.01)
rr.fit(X_train, y_train) 
la_p = la.predict(X_test) 
rr_p = rr.predict(X_test)

# %%
calculate_metrics(y_test, la_p)
# Out:
# MSE:-  1.0717281493001305
# RMSE:-  1.0352430387595613
# R2_score:-  0.9901367095833798

# %%
calculate_metrics(y_test, rr_p)
# Out:
# MSE:-  0.5776768758959114
# RMSE:-  0.7600505745645558
# R2_score:-  0.9946835447052053

# %%
from sklearn.svm import SVR 
from sklearn.model_selection import GridSearchCV 

svr = SVR() 


param_grid = {'C': [0.1, 1, 10, 100, 1000],  
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
              'kernel': ['rbf']}   

grid = GridSearchCV(SVR(), param_grid, refit=True, verbose=3)    
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.148 total time=   0.0s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.202 total time=   0.0s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.008 total time=   0.0s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.078 total time=   0.0s
# [CV 5/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.027 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.148 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.202 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.008 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.078 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.027 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.148 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.202 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.008 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.078 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.027 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.148 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.202 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.008 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.078 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.027 total time=   0.0s
# [CV 1/5] END ..C=0.1, gamma=0.0001, kernel=rbf;, score=-0.148 total time=   0.0s
# [CV 2/5] END ..C=0.1, gamma=0.0001, kernel=rbf;, score=-0.202 total time=   0.0s
# [CV 3/5] END ..C=0.1, gamma=0.0001, kernel=rbf;, score=-0.008 total time=   0.0s
# [CV 4/5] END ..C=0.1, gamma=0.0001, kernel=rbf;, score=-0.078 total time=   0.0s
# [CV 5/5] END ..C=0.1, gamma=0.0001, kernel=rbf;, score=-0.027 total time=   0.0s
# [CV 1/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.148 total time=   0.0s
# [CV 2/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.198 total time=   0.0s
# [CV 3/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.005 total time=   0.0s
# [CV 4/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.074 total time=   0.0s
# [CV 5/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.023 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.148 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.198 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.005 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.074 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.023 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.148 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.198 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.005 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.074 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.023 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.148 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.198 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.005 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.074 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.023 total time=   0.0s
# [CV 1/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.148 total time=   0.0s
# [CV 2/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.198 total time=   0.0s
# [CV 3/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.005 total time=   0.0s
# [CV 4/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.074 total time=   0.0s
# [CV 5/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.023 total time=   0.0s
# [CV 1/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.070 total time=   0.0s
# [CV 2/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.101 total time=   0.0s
# [CV 3/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.005 total time=   0.0s
# [CV 4/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.030 total time=   0.0s
# [CV 5/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.001 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-0.070 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-0.101 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-0.005 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-0.030 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-0.001 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.070 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.101 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.005 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.030 total time=   0.0s
# [CV 5/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.001 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.070 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.101 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.005 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.030 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.001 total time=   0.0s
# [CV 1/5] END ...C=10, gamma=0.0001, kernel=rbf;, score=-0.070 total time=   0.0s
# [CV 2/5] END ...C=10, gamma=0.0001, kernel=rbf;, score=-0.101 total time=   0.0s
# [CV 3/5] END ...C=10, gamma=0.0001, kernel=rbf;, score=-0.005 total time=   0.0s
# [CV 4/5] END ...C=10, gamma=0.0001, kernel=rbf;, score=-0.030 total time=   0.0s
# [CV 5/5] END ...C=10, gamma=0.0001, kernel=rbf;, score=-0.001 total time=   0.0s
# [CV 1/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.015 total time=   0.0s
# [CV 2/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.027 total time=   0.0s
# [CV 3/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.052 total time=   0.0s
# [CV 4/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.004 total time=   0.0s
# [CV 5/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.044 total time=   0.0s
# [CV 1/5] END .....C=100, gamma=0.1, kernel=rbf;, score=-0.015 total time=   0.0s
# [CV 2/5] END .....C=100, gamma=0.1, kernel=rbf;, score=-0.027 total time=   0.0s
# [CV 3/5] END .....C=100, gamma=0.1, kernel=rbf;, score=-0.052 total time=   0.0s
# [CV 4/5] END .....C=100, gamma=0.1, kernel=rbf;, score=-0.004 total time=   0.0s
# [CV 5/5] END .....C=100, gamma=0.1, kernel=rbf;, score=-0.044 total time=   0.0s
# [CV 1/5] END ....C=100, gamma=0.01, kernel=rbf;, score=-0.015 total time=   0.0s
# [CV 2/5] END ....C=100, gamma=0.01, kernel=rbf;, score=-0.027 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.01, kernel=rbf;, score=-0.052 total time=   0.0s
# [CV 4/5] END ....C=100, gamma=0.01, kernel=rbf;, score=-0.004 total time=   0.0s
# [CV 5/5] END ....C=100, gamma=0.01, kernel=rbf;, score=-0.044 total time=   0.0s
# [CV 1/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.015 total time=   0.0s
# [CV 2/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.027 total time=   0.0s
# [CV 3/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.052 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.004 total time=   0.0s
# [CV 5/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.044 total time=   0.0s
# [CV 1/5] END ..C=100, gamma=0.0001, kernel=rbf;, score=-0.015 total time=   0.0s
# [CV 2/5] END ..C=100, gamma=0.0001, kernel=rbf;, score=-0.027 total time=   0.0s
# [CV 3/5] END ..C=100, gamma=0.0001, kernel=rbf;, score=-0.052 total time=   0.0s
# [CV 4/5] END ..C=100, gamma=0.0001, kernel=rbf;, score=-0.004 total time=   0.0s
# [CV 5/5] END ..C=100, gamma=0.0001, kernel=rbf;, score=-0.044 total time=   0.0s
# [CV 1/5] END ......C=1000, gamma=1, kernel=rbf;, score=-0.015 total time=   0.0s
# [CV 2/5] END ......C=1000, gamma=1, kernel=rbf;, score=-0.027 total time=   0.0s
# [CV 3/5] END ......C=1000, gamma=1, kernel=rbf;, score=-0.052 total time=   0.0s
# [CV 4/5] END ......C=1000, gamma=1, kernel=rbf;, score=-0.004 total time=   0.0s
# [CV 5/5] END ......C=1000, gamma=1, kernel=rbf;, score=-0.044 total time=   0.0s
# [CV 1/5] END ....C=1000, gamma=0.1, kernel=rbf;, score=-0.015 total time=   0.0s
# [CV 2/5] END ....C=1000, gamma=0.1, kernel=rbf;, score=-0.027 total time=   0.0s
# [CV 3/5] END ....C=1000, gamma=0.1, kernel=rbf;, score=-0.052 total time=   0.0s
# [CV 4/5] END ....C=1000, gamma=0.1, kernel=rbf;, score=-0.004 total time=   0.0s
# [CV 5/5] END ....C=1000, gamma=0.1, kernel=rbf;, score=-0.044 total time=   0.0s
# [CV 1/5] END ...C=1000, gamma=0.01, kernel=rbf;, score=-0.015 total time=   0.0s
# [CV 2/5] END ...C=1000, gamma=0.01, kernel=rbf;, score=-0.027 total time=   0.0s
# [CV 3/5] END ...C=1000, gamma=0.01, kernel=rbf;, score=-0.052 total time=   0.0s
# [CV 4/5] END ...C=1000, gamma=0.01, kernel=rbf;, score=-0.004 total time=   0.0s
# [CV 5/5] END ...C=1000, gamma=0.01, kernel=rbf;, score=-0.044 total time=   0.0s
# [CV 1/5] END ..C=1000, gamma=0.001, kernel=rbf;, score=-0.015 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.001, kernel=rbf;, score=-0.027 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.001, kernel=rbf;, score=-0.052 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.001, kernel=rbf;, score=-0.004 total time=   0.0s
# [CV 5/5] END ..C=1000, gamma=0.001, kernel=rbf;, score=-0.044 total time=   0.0s
# [CV 1/5] END .C=1000, gamma=0.0001, kernel=rbf;, score=-0.015 total time=   0.0s
# [CV 2/5] END .C=1000, gamma=0.0001, kernel=rbf;, score=-0.027 total time=   0.0s
# [CV 3/5] END .C=1000, gamma=0.0001, kernel=rbf;, score=-0.052 total time=   0.0s
# [CV 4/5] END .C=1000, gamma=0.0001, kernel=rbf;, score=-0.004 total time=   0.0s
# [CV 5/5] END .C=1000, gamma=0.0001, kernel=rbf;, score=-0.044 total time=   0.0s
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
svr = SVR(C=10, gamma=0.01, kernel='rbf') 
svr.fit(X_train, y_train) 
svr_pred = svr.predict(X_test)

# %%
import joblib  

joblib.dump(rr, 'model.pkl') 

ridge_from_joblib = model = joblib.load("model.pkl")

# %%
# import pickle
# df=pd.read_pickle('model.pkl')
# print(df)

# %%
def preprocess(Open,High,Low,Volume):
    test_data=num.array([[Open,High,Low,Volume]])
    trained_model=joblib.load("model.pkl")
    prediction=trained_model.predict(test_data)
    return prediction
t=preprocess(97.31,100.32,97.31,27556600)
print("Predicted Value for the given stock is: ",t)
# Out:
# Predicted Value for the given stock is:  [99.95987806]
# C:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(
